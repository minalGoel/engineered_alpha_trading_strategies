# %%
import pandas as pd

# %%
data = pd.read_parquet('option_candles.parquet')
data.head(5)
# Out:
#                   symbol         underlying session_date      expiry   strike  \
# 0  NSE:NIFTY2631024700CE  NSE:NIFTY50-INDEX   2026-03-04  2026-03-10  24700.0
# 1  NSE:NIFTY2631024700CE  NSE:NIFTY50-INDEX   2026-03-04  2026-03-10  24700.0
# 2  NSE:NIFTY2631024700CE  NSE:NIFTY50-INDEX   2026-03-04  2026-03-10  24700.0
# 3  NSE:NIFTY2631024700CE  NSE:NIFTY50-INDEX   2026-03-04  2026-03-10  24700.0
# 4  NSE:NIFTY2631024700CE  NSE:NIFTY50-INDEX   2026-03-04  2026-03-10  24700.0
#
#   option_type       epoch                  ts    open    high     low   close  \
# 0          CE  1772595900 2026-03-04 03:45:00  179.85  179.85  126.70  149.95
# 1          CE  1772595905 2026-03-04 03:45:05  151.35  159.00  140.05  140.10
# 2          CE  1772595910 2026-03-04 03:45:10  139.45  139.45  125.95  131.45
# 3          CE  1772595915 2026-03-04 03:45:15  134.75  139.80  133.20  139.80
# 4          CE  1772595920 2026-03-04 03:45:20  140.20  140.20  135.05  135.40
#
#    volume  open_interest
# 0  122720         771030
# 1   87100         771030
# 2  111085         771030
# 3   90090         771030
# 4   72280         771030

# %%
data['underlying'].value_counts()
# Out:
# underlying
# NSE:NIFTYBANK-INDEX    1474270
# NSE:NIFTY50-INDEX      1196978
# Name: count, dtype: int64

# %%
data = pd.read_parquet('spot_candles.parquet')
data.head(5)
# Out:
#                symbol session_date       epoch                  ts   open  \
# 0  NSE:INDIAVIX-INDEX   2025-12-01  1764560700 2025-12-01 03:45:00  11.62
# 1  NSE:INDIAVIX-INDEX   2025-12-01  1764560705 2025-12-01 03:45:05  11.24
# 2  NSE:INDIAVIX-INDEX   2025-12-01  1764560710 2025-12-01 03:45:10  11.28
# 3  NSE:INDIAVIX-INDEX   2025-12-01  1764560715 2025-12-01 03:45:15  11.25
# 4  NSE:INDIAVIX-INDEX   2025-12-01  1764560720 2025-12-01 03:45:20  11.31
#
#     high    low  close  volume
# 0  11.62  10.90  11.23       0
# 1  11.49  10.92  11.19       0
# 2  11.28  11.23  11.26       0
# 3  11.30  11.24  11.30       0
# 4  11.31  11.30  11.30       0

# %%
data[data['symbol'] == 'NSE:NIFTYBANK-INDEX'].head(2)
# Out:
#                     symbol session_date       epoch                  ts  \
# 54000  NSE:NIFTYBANK-INDEX   2026-03-04  1772595900 2026-03-04 03:45:00
# 54001  NSE:NIFTYBANK-INDEX   2026-03-04  1772595905 2026-03-04 03:45:05
#
#            open     high       low     close   volume
# 54000  58447.15  58574.3  58393.55  58574.30  2177493
# 54001  58586.00  58907.5  58586.00  58875.95  1408604

# %%
data['symbol'].value_counts()
# Out:
# symbol
# NSE:NIFTY50-INDEX      319500
# NSE:INDIAVIX-INDEX     301500
# NSE:NIFTYBANK-INDEX    301500
# Name: count, dtype: int64

# %%
data['ts'].min() + pd.Timedelta(hours=5, minutes=30)
# Out:
# Timestamp('2026-03-04 09:15:00')
